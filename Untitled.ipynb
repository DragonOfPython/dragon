# %%
# -----------------------------------------------------------------------------
# Copyright (c) 2015, Nicolas P. Rougier. All Rights Reserved.
# Distributed under the (new) BSD License. See LICENSE.txt for more info.
# -----------------------------------------------------------------------------
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('dark_background')

eqs = []
eqs.append((r"$W^{3\beta}_{\delta_1 \rho_1 \sigma_2} = U^{3\beta}_{\delta_1 \rho_1} + \frac{1}{8 \pi 2} \int^{\alpha_2}_{\alpha_2} d \alpha^\prime_2 \left[\frac{ U^{2\beta}_{\delta_1 \rho_1} - \alpha^\prime_2U^{1\beta}_{\rho_1 \sigma_2} }{U^{0\beta}_{\rho_1 \sigma_2}}\right]$"))
eqs.append((r"$\frac{d\rho}{d t} + \rho \vec{v}\cdot\nabla\vec{v} = -\nabla p + \mu\nabla^2 \vec{v} + \rho \vec{g}$"))
eqs.append((r"$\int_{-\infty}^\infty e^{-x^2}dx=\sqrt{\pi}$"))
eqs.append((r"$E = mc^2 = \sqrt{{m_0}^2c^4 + p^2c^2}$"))
eqs.append((r"$F_G = G\frac{m_1m_2}{r^2}$"))


plt.axes([0.025,0.025,0.95,0.95])

for i in range(24):
    index = np.random.randint(0,len(eqs))
    eq = eqs[index]
    size = np.random.uniform(12,32)
    x,y = np.random.uniform(0,1,2)
    alpha = np.random.uniform(0.25,.75)
    plt.text(x, y, eq, ha='center', va='center', color="#11557c", alpha=alpha,
             transform=plt.gca().transAxes, fontsize=size, clip_on=True)

plt.xticks([]), plt.yticks([])
# savefig('../figures/text_ex.png',dpi=48)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt 
from numpy.core.multiarray import square

ages_x = np.array ([25, 26, 28, 29, 30, 31, 32, 33, 34, 35, 45]) 

dev_y = np.array([38000, 42000, 46752, 49320, 53200, 56000, 62316, 64583, 67529, 77777, 50056])

plt.plot(ages_x, dev_y, label='Husan')

py_dev_y = np.array([37830, 45400, 49394, 50650, 54875, 57860, 65316, 66583, 68943, 79647, 80125])

plt.plot(ages_x, py_dev_y, label='Python')



plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) by Age')

plt.legend(['Husan', 'Pyhton'])

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt 
from numpy.core.multiarray import square


ages_x = np.array ([25, 26, 28, 29, 30, 31, 32, 33, 34, 35, 45]) 

py_dev_y = np.array([37830, 45400, 49394, 50650, 54875, 57860, 65316, 66583, 68943, 79647, 80125])

plt.plot(ages_x, py_dev_y, color='#5a7d9a', linewidth=3, label='Python')

js_dev_y = np.array([32300, 35687, 40954, 42876, 47485, 48731, 50973, 56483, 57023, 58739, 67056])

plt.plot(ages_x, js_dev_y, color='#adad3b', linewidth=3, label='JavaScript')

dev_y = np.array([38000, 42000, 46752, 49320, 53200, 56000, 62316, 64583, 67529, 77777, 50056])

plt.plot(ages_x, dev_y, color='#444444',linestyle='--',label='Husan')

plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) by Age')

plt.legend()

plt.grid(True)

plt.tight_layout()

#plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt 
from numpy.core.multiarray import square


ages_x = np.array ([25, 26, 28, 29, 30, 31, 32, 33, 34, 35, 45]) 

py_dev_y = np.array([37830, 45400, 49394, 50650, 54875, 57860, 65316, 66583, 68943, 79647, 80125])

plt.plot(ages_x, py_dev_y, color='#5a7d9a', linewidth=3, label='Python')

js_dev_y = np.array([32300, 35687, 40954, 42876, 47485, 48731, 50973, 56483, 57023, 58739, 67056])

plt.plot(ages_x, js_dev_y, color='#adad3b', linewidth=3, label='JavaScript')

dev_y = np.array([38000, 42000, 46752, 49320, 53200, 56000, 62316, 64583, 67529, 77777, 50056])

plt.plot(ages_x, dev_y, color='#444444',linestyle='--',label='Husan')

plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) by Age')

plt.legend()

plt.grid()

#plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt 
from numpy.core.multiarray import square

ages_x = np.array ([25, 26, 28, 29, 30, 31, 32, 33, 34, 35, 45]) 

py_dev_y = np.array([37830, 45400, 49394, 50650, 54875, 57860, 65316, 66583, 68943, 79647, 80125])

plt.bar(ages_x, py_dev_y, color='#5a7d9a', linewidth=3, label='Python')

js_dev_y = np.array([32300, 35687, 40954, 42876, 47485, 48731, 50973, 56483, 57023, 58739, 67056])

plt.bar(ages_x, js_dev_y, color='#adad3b', linewidth=3, label='JavaScript')

dev_y = np.array([38000, 42000, 46752, 49320, 53200, 56000, 62316, 64583, 67529, 77777, 50056])

plt.bar(ages_x, dev_y, color='#444444',linestyle='--',label='Husan')

plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) by Age')

plt.legend()

plt.tight_layout()

plt.grid()

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt 
from numpy.core.multiarray import square

plt.style.use('fivethirtyeight')

ages_x = [25, 26, 28, 29, 30, 31, 32, 33, 34, 35]

x_indexes= np.arange(len(ages_x))
width = 0.25

dev_y = [48000, 52000, 56752, 59320, 63200, 66000, 72316, 74583, 77529, 87777]

plt.bar(x_indexes - width, dev_y, width = width, color='#008fd5',linestyle='--',label='Husan')

py_dev_y = [37830, 45400, 49394, 50650, 54875, 57860, 65316, 66583, 68943, 79647]

plt.bar(x_indexes, py_dev_y, width = width, color='#444444', label='Python')

js_dev_y = [32300, 35687, 40954, 42876, 47485, 48731, 50973, 56483, 57023, 58739]

plt.bar(x_indexes + width, js_dev_y, width = width, color='#adad3b', label='JavaScript')

plt.legend()
plt.xticks(ticks=x_indexes, labels= ages_x)

plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')
plt.title('Median Salary (USD) by Age')

plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from numpy.core.multiarray import square


plt.rcParams["figure.figsize"] = [3.58, 8.50]
plt.rcParams["figure.autolayout"] = True

def f(x):
   return -1/x+15.21/((x**2))-15.21/(x**3)
x = np.setdiff1d(np.linspace(6,400,3000,310),[0])
plt.plot(x, f(x), linewidth=2,color='blue')

plt.xlabel('r')
plt.ylabel('V_eff')
plt.title('Plot of effective potential')

plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt

plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

def f(x):
   return np.sin(x) + x + x * np.sin(x)

x = np.linspace(-10, 10, 100)

plt.plot(x, f(x), linewidth=2, color='red')

plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of somewhat function')


plt.show()
